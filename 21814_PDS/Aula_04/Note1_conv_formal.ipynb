# %% [markdown]
# 2.b[n] = n[n-2]
# h[]
#
# x[-2]   =                   =   0
# x[-1]   = 2.b[-2] + [-2-2]  =   0
# x[0]    = 2.0.25 + 0 + 1.0  =   0.5
# x[1]    = 2.0.25 + 0 + 1.0  =   0.5
# x[2]    = 2.0.25 + 0 + 1.0.25 =  0.25+0.5 = 0.75
# x[3]    =                   =   0.75
# x[4]    =                   =   0.75
# x[]

# %% [markdown]
# x[n] = (0.5) exp n * u[n]  p> 0<n<=4
#
# h[n] = 4 * ( u[n] - u[n-5]) =
#
#         4 *
#
# a)                          1--
#                       _________|__|__|__|__|______
#                        -2  -1  0  1  2  3  4  5
# -
#
# b)                                          1--
#                       _________o__o__o__o__o__|____
#                        -2  -1  0  1  2  3  4  5
#
#                             4--|  |  |  |  |
#                                |  |  |  |  |
#                                |  |  |  |  |
#                       _________|__|__|__|__|______
#                        -2  -1  0  1  2  3  4  5

# %% [markdown]
# x[n] = 1, 0, -1, 0, 1
# h[n] = 0.1, 0.4, 0.5, 0.4, 0.1
#
#
# x)                          1--             --1
#                       _________|__o_____o__|______
#                                      |
#                                      -1
#                        -2  -1  0  1  2  3  4  5
# -
#
# h)n=0                                 -0.5
#                                      |
#                              0.4- |  |  |-0.4
#                                   |  |  |
#                            0.1-   |  |  |   -0.1
#                       _________|__|__|__|__|_____
#                        -2  -1  0  1  2  3  4  5
#
#
#  n=1                               -0.5
#                                  |
#                          0.4- |  |  |-0.4
#                               |  |  |
#                        0.1-   |  |  |   -0.1
#                   _________|__|__|__|__|_____
#                    -2  -1  0  1  2  3  4  5
#
#
# n = 2
